# %% [markdown]
# **1. Read dataset**

# %%
from nltk.corpus import reuters
from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer
import re
from nltk.corpus import stopwords
from collections import Counter

import gensim
import warnings
from sklearn import manifold
from sklearn import metrics

from gensim.models import Word2Vec
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import random
import string

import faiss

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader

import sys 
sys.path.append("..") 
sys.path.append("../..") 

import pcl.loader
import pcl.builder2

from copy import deepcopy
from sklearn.model_selection import train_test_split

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
seed = 1

def setup_seed(seed=seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
f = open('output.txt', 'a')
f.write('seed: ' + str(seed) + '\n')
f.close()

# %%
normal_documents = reuters.fileids(categories=['earn', 'acq'])
abnormal_document = reuters.fileids(categories=['interest', 'wheat', 'dlr', 'gnp', 'crude'])

train_normal_docs = list(filter(lambda doc: doc.startswith("train"), normal_documents));
train_abnormal_docs = list(filter(lambda doc: doc.startswith("train"), abnormal_document));

test_normal_docs = list(filter(lambda doc: doc.startswith("test"), normal_documents));
test_abnormal_docs = list(filter(lambda doc: doc.startswith("test"), abnormal_document));

print('Number of train documents:', len(train_normal_docs), len(train_abnormal_docs))
print('Number of test documents:', len(test_normal_docs), len(test_abnormal_docs))
# Out:
# Number of train documents: 4511 1160
# Number of test documents: 1803 465

# %%
cachedStopWords = stopwords.words("english")
 
def tokenize(text):
    min_length = 3
    words = map(lambda word: word.lower(), word_tokenize(text));
    words = [word for word in words if word not in cachedStopWords]
    tokens =(list(map(lambda token: SnowballStemmer("english", ignore_stopwords=True).stem(token), words)));
    p = re.compile('[a-zA-Z]+');
    filtered_tokens = list(filter(lambda token: p.match(token) and len(token)>=min_length, tokens));
    return filtered_tokens

# %%
setup_seed()

def sequence_list(docs):
    corups = []
    doc_index = []
    for doc in docs:
        document_words = reuters.words(doc)
        corups.append(tokenize(' '.join(document_words)))
        doc_index.append(doc)
    return corups, doc_index

train_normal_corups, train_normal_doc_index = sequence_list(train_normal_docs)
train_abnormal_corups, train_abnormal_doc_index = sequence_list(train_abnormal_docs)

test_normal_corups, test_normal_doc_index = sequence_list(test_normal_docs)
test_abnormal_corups, test_abnormal_doc_index = sequence_list(test_abnormal_docs)

train_corups = train_normal_corups + train_abnormal_corups
test_corups = test_normal_corups + test_abnormal_corups

train_corups_index = train_normal_doc_index + train_abnormal_doc_index
test_corups_index = test_normal_doc_index + test_abnormal_doc_index

train_labels = [0]*len(train_normal_corups) + [1]*len(train_abnormal_corups)
test_labels = [0]*len(test_normal_corups) + [1]*len(test_abnormal_corups)

train_dataset = pd.DataFrame({'EventId': train_corups, 'Label':train_labels, 'Doc': train_corups_index})
test_dataset = pd.DataFrame({'EventId': test_corups, 'Label':test_labels, 'Doc': test_corups_index})

train_normal_ds = train_dataset[train_dataset['Label']==0].sample(n=1100, replace=False)
train_abnormal_ds = train_dataset[train_dataset['Label']==1].sample(n=220, replace=False)

val_normal_ds = train_normal_ds.sample(n=100, replace=False)
val_abnormal_ds = train_abnormal_ds.sample(n=20, replace=False)
val_ds = pd.concat([val_normal_ds, val_abnormal_ds])

train_normal_ds = train_normal_ds.drop(val_normal_ds.index)
train_abnormal_ds = train_abnormal_ds.drop(val_abnormal_ds.index)
train_ds = pd.concat([train_normal_ds, train_abnormal_ds])

test_normal_ds = test_dataset[test_dataset['Label']==0].sample(n=1000, replace=False)
test_abnormal_ds = test_dataset[test_dataset['Label']==1].sample(n=200, replace=False)
test_ds =pd.concat([test_normal_ds, test_abnormal_ds])

# %% [markdown]
# **2. Preprocessing**

# %%
word2vec = Word2Vec(sentences=train_corups, vector_size=100, window=5, min_count=1, workers=4)

word2vec.wv.vectors = np.append(word2vec.wv.vectors, np.zeros((1, 100), dtype=np.float32), axis=0)
word2vec.wv.vectors = np.append(word2vec.wv.vectors, np.random.randn(1, 100).astype(np.float32), axis=0)

# %%
def encode_sequence(sequence, logkey2index):
    return [logkey2index.get(logkey, len(word2vec.wv.key_to_index)+1) for logkey in sequence]

train_ds.loc[:, 'Encoded'] = train_ds.loc[:, 'EventId'].apply(lambda x: encode_sequence(x, word2vec.wv.key_to_index))
val_ds.loc[:, 'Encoded'] = val_ds.loc[:, 'EventId'].apply(lambda x: encode_sequence(x, word2vec.wv.key_to_index))
test_ds.loc[:, 'Encoded'] = test_ds.loc[:, 'EventId'].apply(lambda x: encode_sequence(x, word2vec.wv.key_to_index))

# %%
setup_seed()

with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    def compose_pairs(dataset):
        number_seq = dataset.shape[0]
        
        data_aug_list = []
        
        for i in range(number_seq):
            sequence = dataset.iloc[i, 3]
            a, b = np.random.choice(len(sequence), 2)
            
            seq_aug1 = deepcopy(sequence)
            seq_aug1.pop(a)
            seq_aug2 = deepcopy(sequence)
            seq_aug2.pop(b)
            data_aug_list.append([seq_aug1, seq_aug2])

        dataset['Pair0'] = pd.Series([x[0] for x in data_aug_list]).values
        dataset['Pair1'] = pd.Series([x[1] for x in data_aug_list]).values
        
        return dataset

train_ds2 = compose_pairs(train_ds)
val_ds2 = compose_pairs(val_ds)
test_ds2 = compose_pairs(test_ds)

train_ds2['Index'] = range(train_ds2.shape[0])
val_ds2['Index'] = range(val_ds2.shape[0])
test_ds2['Index'] = range(test_ds2.shape[0])

# %%
batch_size_train = 20
batch_size_val = 20
batch_size_test = 20

# %%
def collate_fn(data_list):
    data_list.sort(key=lambda x: len(x[0]), reverse=True)
    sequence = [torch.tensor(x[0]) for x in data_list]
    label = [x[1] for x in data_list]
    sequence_length = [len(x[0]) for x in data_list]
    index = [x[2] for x in data_list]
    
    seq_aug1 = [torch.tensor(x[3]) for x in data_list]
    seq_aug2 = [torch.tensor(x[4]) for x in data_list]
    
    doc = [x[5] for x in data_list]

    padded_sequence = pad_sequence(sequence, batch_first=True, padding_value=len(word2vec.wv.key_to_index))
    padded_seq_aug1 = pad_sequence(seq_aug1, batch_first=True, padding_value=len(word2vec.wv.key_to_index))
    padded_seq_aug2 = pad_sequence(seq_aug2, batch_first=True, padding_value=len(word2vec.wv.key_to_index))
    return index, padded_sequence, label, sequence_length, padded_seq_aug1, padded_seq_aug2, doc

# %%
train_data_list = train_ds[['Encoded', 'Label', 'Index', 'Pair0', 'Pair1', 'Doc']].values.tolist()
val_data_list = val_ds[['Encoded', 'Label', 'Index', 'Pair0', 'Pair1', 'Doc']].values.tolist()
test_data_list = test_ds[['Encoded', 'Label', 'Index', 'Pair0', 'Pair1', 'Doc']].values.tolist()

train_loader = DataLoader(train_data_list, batch_size=batch_size_train, collate_fn=collate_fn, drop_last=True)
val_loader = DataLoader(val_data_list, batch_size=batch_size_train, collate_fn=collate_fn, drop_last=True)
test_loader = DataLoader(test_data_list, batch_size=batch_size_test, collate_fn=collate_fn, drop_last=True)

# %% [markdown]
# **3. Model**

# %%
vocab_size = len(word2vec.wv.key_to_index)
embedding_dim = 100
hidden_dim = 256
num_layers = 2
epochs = 100
num_cluster_n = ['2']
num_cluster_a = ['7']

f = open('output.txt', 'a')
f.write('Abnormal clusters: ' + num_cluster_a[0] + '\n')
f.close()

num_cluster = [str(int(num_cluster_n[i]) + int(num_cluster_a[i])) for i in range(len(num_cluster_n))]

# %%
class SequenceEncoder(nn.Module):
    def __init__(self, vocab_size=vocab_size, embedding_dim=embedding_dim, 
                 hidden_dim=hidden_dim, num_layers=num_layers, num_classes=2):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.embeddings = nn.Embedding.from_pretrained(torch.from_numpy(word2vec.wv.vectors))
        self.embeddings.requires_grad = True
        self.lstm = nn.LSTM(input_size=embedding_dim,
                            hidden_size=hidden_dim,
                            num_layers=num_layers,
                            batch_first=True,
                            bias=True)

    def forward(self, seq):
        seq_length = [len(x)-x.count(len(word2vec.wv.key_to_index)) for x in seq.tolist()]
        embedded = self.embeddings(seq)
        packed_embedded = pack_padded_sequence(embedded, seq_length, batch_first=True,enforce_sorted=False)
        packed_out, (hidden, cell) = self.lstm(packed_embedded)
        out, len_list = pad_packed_sequence(packed_out, batch_first=True) 
        mean_hidden = torch.sum(out, dim=1) / len_list.view(-1, 1).to(device)
        return nn.functional.normalize(mean_hidden, dim=1)

# %%
setup_seed()

model = pcl.builder2.MoCo(SequenceEncoder,hidden_dim, 200, 0.999, 0.05).to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(model.parameters(), 0.001, weight_decay=1e-6)

# %% [markdown]
# **4. Training**

# %%
def compute_features(train_ds, model):
    model.eval()
    seq_label = [len(x)-x.count(len(word2vec.wv.key_to_index)) for x in train_ds.Encoded.tolist()]
    encoded_sequences = [torch.tensor(x) for x in train_ds.Encoded.tolist()]
    padded_sequence = pad_sequence(encoded_sequences, batch_first=True, 
                                   padding_value=len(word2vec.wv.key_to_index)).to(device)
    features = model(padded_sequence, is_eval=True, sequence_label=seq_label)   
    return features.cpu().numpy()

# %%
def run_kmeans(x, num_cluster, temperature):
    """
    Args:
        x: data to be clustered
    """

    results = {'im2cluster': [], 'centroids': [], 'density': []}

    # intialize faiss clustering parameters
    d = x.shape[1]
    k = int(num_cluster[0])
    clus = faiss.Clustering(d, k)
    clus.verbose = True
    clus.niter = 10
    clus.nredo = 5
    clus.seed = seed
    clus.max_points_per_centroid = 1000
    clus.min_points_per_centroid = 1

    res = faiss.StandardGpuResources()
    cfg = faiss.GpuIndexFlatConfig()
    cfg.useFloat16 = False
    cfg.device = 0
    index = faiss.GpuIndexFlatL2(res, d, cfg)

    clus.train(x, index)

    D, I = index.search(x, 3)  # for each sample, find cluster distance and assignments
    im2cluster = [int(n[0]) for n in I]
    # get cluster centroids
    centroids = faiss.vector_to_array(clus.centroids).reshape(k, d)

    # sample-to-centroid distances for each cluster 
    Dcluster = [[] for c in range(k)]
    for im, i in enumerate(im2cluster):
        Dcluster[i].append(D[im][0])

    # concentration estimation (phi)        
    density = np.zeros(k)
    for i, dist in enumerate(Dcluster):
        if len(dist) > 1:
            d = (np.asarray(dist) ** 0.5).mean() / np.log(len(dist) + 10)
            density[i] = d

            # if cluster only has one point, use the max to estimate its concentration
    dmax = density.max()
    for i, dist in enumerate(Dcluster):
        if len(dist) <= 1:
            density[i] = dmax

    density = density.clip(np.percentile(density, 10),
                           np.percentile(density, 90))  # clamp extreme values for stability
    density = temperature * density / density.mean()  # scale the mean to temperature

    # convert to cuda Tensors for broadcast
    centroids = torch.Tensor(centroids).cuda()
    centroids = nn.functional.normalize(centroids, p=2, dim=1)

    im2cluster = torch.LongTensor(im2cluster).cuda()
    density = torch.Tensor(density).cuda()

    results['centroids'] = centroids
    results['density'] = density
    results['im2cluster'] = im2cluster

    return results

# %%
def train_model(train_loader, model, criterion, optimizer, epoch, cluster_result=None):
    model.train()
    
    acc_epoch = []
    loss_epoch = []
    
    for index, sequence, label, _, sequence0, sequence1,_ in train_loader:
        pair0 = sequence0.to(device)
        pair1 = sequence1.to(device)
        label = torch.tensor(label).to(device)

        output, target, output_proto, target_proto = model(im_q=pair0, im_k=pair1, cluster_result=cluster_result, 
                                                           index = index, sequence_label=label)
        info_loss = criterion(output, target)
        
        # ProtoNCE loss
        if output_proto is not None:
            loss_proto = 0
            for proto_out,proto_target in zip(output_proto, target_proto):
                loss_proto += criterion(proto_out, proto_target)

            # average loss across all sets of prototypes
            loss_proto /= len(num_cluster)

        loss = loss_proto + info_loss 
#         print(loss_proto.item(), info_loss.item())

        # losses.update(loss.item(), images[0].size(0))
        loss_epoch.append(loss.item())

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    return np.mean(loss_epoch)

# %%
warnings.filterwarnings('ignore')

setup_seed()

for i in range(epochs):    
    train_normal = train_ds2[train_ds['Label']==0]
    train_abnormal = train_ds2[train_ds['Label']==1]

    features_n = compute_features(train_normal, model)
    cluster_result_n = run_kmeans(features_n, num_cluster_n, 0.05)

    features_a = compute_features(train_abnormal, model)
    cluster_result_a = run_kmeans(features_a, num_cluster_a, 0.05)

    cluster_result_a['im2cluster'] = cluster_result_a['im2cluster'] + int(num_cluster_n[0])

    keys = ['im2cluster', 'centroids', 'density']
    cluster_result = {'im2cluster': [[], [], []], 'centroids': [[], [], []], 'density': [[], [], []]}

    for key in keys:
        cluster_result[key] = torch.cat((cluster_result_n[key], cluster_result_a[key]), 0)
    
    epoch_loss = train_model(train_loader, model, criterion, optimizer, i, cluster_result)
    
    print(f'Epoch {i}: {epoch_loss}')
# Out:
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=59.5577 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=59.5552 imbalance=1.005 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=59.5577 imbalance=1.004 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=59.5577 imbalance=1.004 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=59.5577 imbalance=1.004 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.04732 imbalance=1.374 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.08819 imbalance=1.372 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=6.24298 imbalance=1.204 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=6.99498 imbalance=1.234 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.89847 imbalance=1.142 nsplit=0
# Objective improved: keep new clusters
# Epoch 0: 5.422589755058288
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=74.6269 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=74.6269 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=74.6269 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=74.6269 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=74.6269 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.30522 imbalance=1.373 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.39411 imbalance=1.372 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=7.49009 imbalance=1.289 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.44305 imbalance=1.218 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=7.10556 imbalance=1.128 nsplit=0
# Objective improved: keep new clusters
# Epoch 1: 4.986402332782745
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=99.317 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=99.317 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=99.317 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=99.317 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=99.317 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=9.6708 imbalance=1.361 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=9.30483 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=9.97523 imbalance=1.200 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=11.2731 imbalance=1.202 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=9.24185 imbalance=1.055 nsplit=0
# Objective improved: keep new clusters
# Epoch 2: 4.667578248182933
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=129.432 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=129.432 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=129.432 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=129.432 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=129.432 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=12.8438 imbalance=1.352 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=12.6895 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=13.2231 imbalance=1.194 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.9107 imbalance=1.192 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=12.2509 imbalance=1.055 nsplit=0
# Objective improved: keep new clusters
# Epoch 3: 4.3947501142819725
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=162.208 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=162.208 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=162.208 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=162.208 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=162.208 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=16.5049 imbalance=1.344 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=16.4425 imbalance=1.066 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=16.9089 imbalance=1.201 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=16.7126 imbalance=1.170 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.6952 imbalance=1.055 nsplit=0
# Objective improved: keep new clusters
# Epoch 4: 4.150385296344757
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=195.655 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=195.655 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=195.655 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=195.655 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=195.655 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=20.6477 imbalance=1.249 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=19.8244 imbalance=1.149 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=20.8121 imbalance=1.201 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=20.8221 imbalance=1.108 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=19.3425 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Epoch 5: 3.921978517373403
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=227.545 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=227.545 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=227.545 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=227.545 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=227.545 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=24.3097 imbalance=1.234 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=23.9556 imbalance=1.209 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=24.312 imbalance=1.240 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=24.474 imbalance=1.111 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=22.8584 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Epoch 6: 3.713954782485962
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=257.196 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=257.196 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=257.196 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=257.196 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=257.196 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=27.9108 imbalance=1.234 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=27.4706 imbalance=1.203 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=27.9275 imbalance=1.224 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=28.2292 imbalance=1.085 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=26.3269 imbalance=1.057 nsplit=0
# Objective improved: keep new clusters
# Epoch 7: 3.5269977410634357
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=284.479 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=284.479 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=284.479 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=284.479 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=284.479 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=31.3094 imbalance=1.219 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=29.6664 imbalance=1.165 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=31.2507 imbalance=1.208 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=31.6588 imbalance=1.076 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=29.7739 imbalance=1.078 nsplit=0
# Epoch 8: 3.3884075323740643
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=311.061 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=311.061 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=311.061 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=311.061 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=311.061 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=34.4949 imbalance=1.193 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=32.8291 imbalance=1.158 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=34.6492 imbalance=1.185 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=34.879 imbalance=1.066 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=32.8627 imbalance=1.078 nsplit=0
# Epoch 9: 3.23766934076945
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=335.948 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=335.944 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=335.948 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=335.948 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=335.948 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=37.5366 imbalance=1.203 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=35.8413 imbalance=1.167 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=37.9528 imbalance=1.171 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=36.7945 imbalance=1.135 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=35.8486 imbalance=1.076 nsplit=0
# Epoch 10: 3.075592573483785
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=359.524 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=359.521 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=359.524 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=359.524 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=359.524 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=40.488 imbalance=1.181 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=40.6654 imbalance=1.132 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.6472 imbalance=1.323 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=39.2224 imbalance=1.172 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=38.4087 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Epoch 11: 2.9578209002812703
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=381.536 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=381.553 imbalance=1.010 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=381.536 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=381.536 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=381.536 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.4938 imbalance=1.123 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=42.0751 imbalance=1.101 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=44.0237 imbalance=1.323 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=43.54 imbalance=1.089 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=41.0611 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Epoch 12: 2.8719386875629427
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=403.064 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=403.064 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=403.064 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=403.064 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=403.064 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=46.1995 imbalance=1.182 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.4924 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=47.291 imbalance=1.387 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.4523 imbalance=1.152 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=43.6191 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Epoch 13: 2.773548758029938
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=424.007 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=424.007 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=424.007 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=424.007 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=424.007 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=49.3312 imbalance=1.194 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=47.8377 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=50.3462 imbalance=1.358 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=47.0079 imbalance=1.152 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=46.3188 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Epoch 14: 2.6970385392506917
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=444.284 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=444.284 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=444.284 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=444.284 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=444.284 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=51.9261 imbalance=1.165 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=50.5021 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=52.9173 imbalance=1.344 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=50.2391 imbalance=1.074 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=48.9388 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Epoch 15: 2.628871262073517
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=463.868 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=463.868 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=463.868 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=463.868 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=463.868 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=54.6363 imbalance=1.201 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=52.9544 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=55.5317 imbalance=1.345 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=52.7343 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=51.5251 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Epoch 16: 2.554290227095286
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=482.921 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=482.921 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=482.921 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=482.921 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=482.921 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=57.4518 imbalance=1.219 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=55.4136 imbalance=1.059 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=57.6628 imbalance=1.296 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=55.575 imbalance=1.053 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=54.1878 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Epoch 17: 2.494658861557643
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=501.146 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=501.144 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=501.146 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=501.146 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=501.146 imbalance=1.008 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=60.0726 imbalance=1.226 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=57.9855 imbalance=1.059 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=60.1171 imbalance=1.268 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=58.3947 imbalance=1.078 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=56.6851 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Epoch 18: 2.4467937469482424
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=518.623 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=518.623 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=518.623 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=518.623 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=518.623 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=62.6093 imbalance=1.224 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=60.8357 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=62.9942 imbalance=1.137 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=61.2062 imbalance=1.076 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=59.2338 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Epoch 19: 2.403834368785222
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=535.35 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=535.35 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=535.35 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=535.35 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=535.35 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=65.0923 imbalance=1.205 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=63.6557 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=65.3424 imbalance=1.151 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=63.9423 imbalance=1.075 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=61.7245 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Epoch 20: 2.3621882081031798
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=551.755 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=551.755 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=551.755 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=551.755 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=551.755 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=67.6653 imbalance=1.195 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=66.433 imbalance=1.058 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=68.2929 imbalance=1.286 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=66.048 imbalance=1.066 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=64.1907 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Epoch 21: 2.3319130897521974
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=567.55 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=567.55 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=567.55 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=567.55 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=567.55 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=70.2821 imbalance=1.202 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=69.2524 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=70.3932 imbalance=1.151 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=68.8668 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=66.7771 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Epoch 22: 2.3101806541283927
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=582.462 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=582.462 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=582.462 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=582.462 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=582.462 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=72.9103 imbalance=1.202 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=72.1847 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=73.0908 imbalance=1.140 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=71.6616 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=70.4789 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Epoch 23: 2.29729184905688
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=596.774 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=596.774 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=596.774 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=596.774 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=596.774 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=75.6057 imbalance=1.212 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=74.8849 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=76.8406 imbalance=1.298 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=73.9558 imbalance=1.109 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=73.0369 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Epoch 24: 2.2764092961947124
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=610.115 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=610.115 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=610.115 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=610.115 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=610.115 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=78.2142 imbalance=1.202 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=77.7052 imbalance=1.066 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=80.1152 imbalance=1.225 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=77.9745 imbalance=1.107 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=75.5499 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Epoch 25: 2.255035654703776
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=623.338 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=623.338 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=623.338 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=623.338 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=623.338 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=81.1885 imbalance=1.209 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=81.0019 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=81.3322 imbalance=1.118 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=80.6659 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=78.2316 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Epoch 26: 2.2404463549455005
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=635.916 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=635.916 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=635.916 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=635.916 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=635.916 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=84.0332 imbalance=1.209 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=83.8445 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=84.0688 imbalance=1.120 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=83.424 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=80.9077 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Epoch 27: 2.2264487047990165
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=647.813 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=647.813 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=647.813 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=647.813 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=647.813 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=87.6359 imbalance=1.291 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=86.7631 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=86.8563 imbalance=1.122 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=86.1525 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=83.7242 imbalance=1.083 nsplit=0
# Objective improved: keep new clusters
# Epoch 28: 2.217372010151545
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=658.971 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=658.971 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=658.971 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=658.971 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=658.971 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=90.3382 imbalance=1.281 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=89.8415 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=89.6328 imbalance=1.120 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=88.8468 imbalance=1.103 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=86.3799 imbalance=1.083 nsplit=0
# Objective improved: keep new clusters
# Epoch 29: 2.2100987911224363
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=669.21 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=669.21 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=669.21 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=669.21 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=669.21 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=93.1557 imbalance=1.282 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=93.0706 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=92.217 imbalance=1.136 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=91.548 imbalance=1.103 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=88.8941 imbalance=1.083 nsplit=0
# Objective improved: keep new clusters
# Epoch 30: 2.202426165342331
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=678.561 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=678.561 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=678.561 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=678.561 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=678.561 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=96.0142 imbalance=1.241 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=97.9377 imbalance=1.046 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=94.9639 imbalance=1.138 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=94.2754 imbalance=1.103 nsplit=0
# ...
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.881 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.359 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=129.968 imbalance=1.077 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=134.356 imbalance=1.086 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.015 imbalance=1.237 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=129.918 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 89: 2.153528340657552
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.817 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.817 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.817 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.817 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.817 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.58 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=130.193 imbalance=1.077 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=135.002 imbalance=1.096 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.387 imbalance=1.242 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.141 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 90: 2.153398992617925
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.739 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.739 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.739 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.739 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.739 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.814 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=131.505 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=135.015 imbalance=1.092 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.615 imbalance=1.242 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.368 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 91: 2.1532817125320434
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.652 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.652 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.652 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.652 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.652 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=138.053 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=132.128 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=135.312 imbalance=1.096 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.511 imbalance=1.274 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.595 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 92: 2.1531743745009106
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.557 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.557 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.557 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.557 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.557 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=140.131 imbalance=1.197 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.237 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=136.222 imbalance=1.127 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.271 imbalance=1.288 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.819 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 93: 2.153076978524526
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.453 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.453 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.453 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.453 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.453 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=138.547 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.378 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=136.487 imbalance=1.127 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.471 imbalance=1.288 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.041 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 94: 2.152985845009486
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.344 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.344 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.344 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.344 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.344 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=140.943 imbalance=1.197 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.591 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=136.871 imbalance=1.127 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=142.674 imbalance=1.288 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.259 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 95: 2.152905128399531
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.232 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.232 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.232 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.232 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.232 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=139.222 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=137.877 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=137.127 imbalance=1.163 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=141.404 imbalance=1.304 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.473 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 96: 2.152829372882843
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=776.11 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=776.11 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=776.11 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=776.11 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=776.11 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=139.473 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=138.085 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=137.353 imbalance=1.156 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=141.149 imbalance=1.294 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.68 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 97: 2.152760062615077
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=775.981 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=775.981 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=775.981 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=775.981 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=775.981 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=139.553 imbalance=1.299 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=135.714 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=137.609 imbalance=1.156 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=141.347 imbalance=1.294 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.881 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 98: 2.1526958882808684
# Clustering 1000 points in 256D to 2 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=775.869 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=775.869 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=775.869 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=775.869 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=775.869 imbalance=1.009 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=141.389 imbalance=1.165 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=138.505 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=137.86 imbalance=1.156 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=141.544 imbalance=1.294 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=132.078 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch 99: 2.152639373143514

# %%
# model.load_state_dict(best_val_model)
model.eval()

faiss_search = faiss.IndexFlatL2(cluster_result['centroids'].size(1))
faiss_search.add(cluster_result['centroids'].detach().cpu().numpy())

true_label = []
pred_label = []
doc_index_list = []
doc_type_pred_label = []

for index, sequence, sequence_label, length, _, _, doc in test_loader:
    doc_index_list += doc
    sequence = sequence.to(device)
    
    true_label += sequence_label
    sq = model.encoder_k(sequence).detach().cpu().numpy()
    D, I = faiss_search.search(sq, 1)

    doc_type_pred_label += [i[0] for i in I]
    
    pred_label += [1 if pred>int(num_cluster_n[0])-1 else 0 for pred in I]

# %%
print(metrics.classification_report(true_label, pred_label, digits=4))
print(metrics.confusion_matrix(true_label, pred_label))

fpr, tpr, thresholds = metrics.roc_curve(true_label, pred_label, pos_label=1)
print(metrics.auc(fpr, tpr))

f = open('output.txt', 'a')
f.write('Anomaly detection on testing sequences:'+'\n')
f.write(str(metrics.classification_report(true_label, pred_label, digits=4))+'\n')
f.write(str(metrics.confusion_matrix(true_label, pred_label))+'\n')
f.write(str(metrics.auc(fpr, tpr))+'\n')
f.close()
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9879    0.9810    0.9844      1000
#            1     0.9082    0.9400    0.9238       200
#
#     accuracy                         0.9742      1200
#    macro avg     0.9481    0.9605    0.9541      1200
# weighted avg     0.9746    0.9742    0.9743      1200
#
# [[981  19]
#  [ 12 188]]
# 0.9604999999999999

# %%
test_earn_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['earn'])));
test_acq_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['acq'])));


test_interest_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['interest'])));
test_wheat_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['wheat'])));
test_dlr_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['dlr'])));
test_gnp_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['gnp'])));
test_crude_docs = list(filter(lambda doc: doc.startswith("test"), reuters.fileids(categories=['crude'])));

# %%
doc_type_true_label = []

for each in doc_index_list:
    if each in test_earn_docs:
        doc_type_true_label.append(0)
    
    elif each in test_acq_docs:
        doc_type_true_label.append(1)
    
    elif each in test_interest_docs:
        doc_type_true_label.append(2)
        
    elif each in test_wheat_docs:
        doc_type_true_label.append(3)
        
    elif each in test_dlr_docs:
        doc_type_true_label.append(4)

    elif each in test_gnp_docs:
        doc_type_true_label.append(5)

    elif each in test_crude_docs:
        doc_type_true_label.append(6)

# %%
print(metrics.rand_score(doc_type_true_label, doc_type_pred_label))
print(metrics.mutual_info_score(doc_type_true_label, doc_type_pred_label))

f = open('output.txt', 'a')
f.write('Clustering results:'+'\n')
f.write('rand_score: ' + str(metrics.rand_score(doc_type_true_label, doc_type_pred_label))+'\n')
f.write('mutual_info_score: ' + str(metrics.mutual_info_score(doc_type_true_label, doc_type_pred_label))+'\n')
f.write('-'*50 + '\n')
f.close()
# Out:
# 0.871814011676397
# 0.8548086026489393
