# %% [markdown]
# **1. Read dataset**

# %%
from sklearn.datasets import fetch_20newsgroups
from nltk import word_tokenize
from nltk.stem.snowball import SnowballStemmer
import re
from nltk.corpus import stopwords
from collections import Counter

import gensim
import warnings
from sklearn import manifold
from sklearn import metrics

from gensim.models import Word2Vec
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import random
import string

import faiss

from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import DataLoader

import sys 
sys.path.append("..") 
sys.path.append("../..") 

import pcl.loader
import pcl.builder2

from copy import deepcopy
from sklearn.model_selection import train_test_split

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
seed = 1

def setup_seed(seed=seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
f = open('output.txt', 'a')
f.write('seed: ' + str(seed) + '\n')
f.close()

# %%
cats = [ 'talk.politics.mideast',
 'talk.politics.misc',
 'talk.religion.misc',
 'misc.forsale',
 'rec.sport.baseball',
 'sci.med',
 'soc.religion.christian',
 'rec.autos']

newsgroups_train = fetch_20newsgroups(subset='train', categories=cats)
newsgroups_test = fetch_20newsgroups(subset='test', categories=cats)

# %%
cachedStopWords = stopwords.words("english")
 
def tokenize(text):
    min_length = 3
    words = map(lambda word: word.lower(), word_tokenize(text));
    words = [word for word in words if word not in cachedStopWords]
    tokens =(list(map(lambda token: SnowballStemmer("english", ignore_stopwords=True).stem(token), words)));
    p = re.compile('[a-zA-Z]+');
    filtered_tokens = list(filter(lambda token: p.match(token) and len(token)>=min_length, tokens));
    return filtered_tokens

# %%
setup_seed()

def sequence_list(docs):
    corups = []
    for doc in docs:
        corups.append(tokenize(doc))
    return corups

train_corups = sequence_list(newsgroups_train['data'])
train_labels = np.where(newsgroups_train['target']<3, 0, 1)

test_corups = sequence_list(newsgroups_test['data'])
test_labels = np.where(newsgroups_test['target']<3, 0, 1)

train_dataset = pd.DataFrame({'EventId': train_corups,
                         'Label': train_labels.tolist(),
                         'Type': newsgroups_train['target'].tolist()})
test_dataset = pd.DataFrame({'EventId': test_corups,
                        'Label': test_labels.tolist(),
                        'Type': newsgroups_test['target'].tolist()})

train_normal_ds = train_dataset[train_dataset['Label']==0].sample(n=1100, replace=False)
train_abnormal_ds = train_dataset[train_dataset['Label']==1].sample(n=220, replace=False)

val_normal_ds = train_normal_ds.sample(n=100, replace=False)
val_abnormal_ds = train_abnormal_ds.sample(n=20, replace=False)
val_ds = pd.concat([val_normal_ds, val_abnormal_ds])

train_normal_ds = train_normal_ds.drop(val_normal_ds.index)
train_abnormal_ds = train_abnormal_ds.drop(val_abnormal_ds.index)
train_ds = pd.concat([train_normal_ds, train_abnormal_ds])

test_normal_ds = test_dataset[test_dataset['Label']==0].sample(n=1000, replace=False)
test_abnormal_ds = test_dataset[test_dataset['Label']==1].sample(n=200, replace=False)
test_ds =pd.concat([test_normal_ds, test_abnormal_ds])

# %% [markdown]
# **2. Preprocessing**

# %%
word2vec = Word2Vec(sentences=train_corups, vector_size=100, window=5, min_count=1, workers=4)

word2vec.wv.vectors = np.append(word2vec.wv.vectors, np.zeros((1, 100), dtype=np.float32), axis=0)
word2vec.wv.vectors = np.append(word2vec.wv.vectors, np.random.randn(1, 100).astype(np.float32), axis=0)

# %%
def encode_sequence(sequence, logkey2index):
    return [logkey2index.get(logkey, len(word2vec.wv.key_to_index)+1) for logkey in sequence]

train_ds.loc[:, 'Encoded'] = train_ds.loc[:, 'EventId'].apply(lambda x: encode_sequence(x, word2vec.wv.key_to_index))
val_ds.loc[:, 'Encoded'] = val_ds.loc[:, 'EventId'].apply(lambda x: encode_sequence(x, word2vec.wv.key_to_index))
test_ds.loc[:, 'Encoded'] = test_ds.loc[:, 'EventId'].apply(lambda x: encode_sequence(x, word2vec.wv.key_to_index))

# %%
setup_seed()

with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    def compose_pairs(dataset):
        number_seq = dataset.shape[0]
        
        data_aug_list = []
        
        for i in range(number_seq):
            sequence = dataset.iloc[i, 3]
            a, b = np.random.choice(len(sequence), 2)
            
            seq_aug1 = deepcopy(sequence)
            seq_aug1.pop(a)
            seq_aug2 = deepcopy(sequence)
            seq_aug2.pop(b)
            data_aug_list.append([seq_aug1, seq_aug2])

        dataset['Pair0'] = pd.Series([x[0] for x in data_aug_list]).values
        dataset['Pair1'] = pd.Series([x[1] for x in data_aug_list]).values
        
        return dataset

train_ds2 = compose_pairs(train_ds)
val_ds2 = compose_pairs(val_ds)
test_ds2 = compose_pairs(test_ds)

train_ds2['Index'] = range(train_ds2.shape[0])
val_ds2['Index'] = range(val_ds2.shape[0])
test_ds2['Index'] = range(test_ds2.shape[0])

# %%
batch_size_train = 50
batch_size_val = 20
batch_size_test = 1200

# %%
def collate_fn(data_list):
    data_list.sort(key=lambda x: len(x[0]), reverse=True)
    sequence = [torch.tensor(x[0]) for x in data_list]
    label = [x[1] for x in data_list]
    sequence_length = [len(x[0]) for x in data_list]
    index = [x[2] for x in data_list]
    
    seq_aug1 = [torch.tensor(x[3]) for x in data_list]
    seq_aug2 = [torch.tensor(x[4]) for x in data_list]
    
    type = [x[5] for x in data_list]

    padded_sequence = pad_sequence(sequence, batch_first=True, padding_value=len(word2vec.wv.key_to_index))
    padded_seq_aug1 = pad_sequence(seq_aug1, batch_first=True, padding_value=len(word2vec.wv.key_to_index))
    padded_seq_aug2 = pad_sequence(seq_aug2, batch_first=True, padding_value=len(word2vec.wv.key_to_index))
    return index, padded_sequence, label, sequence_length, padded_seq_aug1, padded_seq_aug2, type

# %%
train_data_list = train_ds[['Encoded', 'Label', 'Index', 'Pair0', 'Pair1', 'Type']].values.tolist()
val_data_list = val_ds[['Encoded', 'Label', 'Index', 'Pair0', 'Pair1', 'Type']].values.tolist()
test_data_list = test_ds[['Encoded', 'Label', 'Index', 'Pair0', 'Pair1', 'Type']].values.tolist()

train_loader = DataLoader(train_data_list, batch_size=batch_size_train, collate_fn=collate_fn, drop_last=True)
val_loader = DataLoader(val_data_list, batch_size=batch_size_train, collate_fn=collate_fn, drop_last=True)
test_loader = DataLoader(test_data_list, batch_size=batch_size_test, collate_fn=collate_fn, drop_last=True)

# %% [markdown]
# **3. Model**

# %%
vocab_size = len(word2vec.wv.key_to_index)
embedding_dim = 100
hidden_dim = 256
num_layers = 2
epochs = 200
num_cluster_n = ['3']
num_cluster_a = ['7']

f = open('output.txt', 'a')
f.write('Abnormal clusters: ' + num_cluster_a[0] + '\n')
f.close()

num_cluster = [str(int(num_cluster_n[i]) + int(num_cluster_a[i])) for i in range(len(num_cluster_n))]

# %%
class SequenceEncoder(nn.Module):
    def __init__(self, vocab_size=vocab_size, embedding_dim=embedding_dim, 
                 hidden_dim=hidden_dim, num_layers=num_layers, num_classes=2):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.embeddings = nn.Embedding.from_pretrained(torch.from_numpy(word2vec.wv.vectors))
        self.embeddings.requires_grad = True
        self.lstm = nn.LSTM(input_size=embedding_dim,
                            hidden_size=hidden_dim,
                            num_layers=num_layers,
                            batch_first=True,
                            bias=True)

    def forward(self, seq):
        seq_length = [len(x)-x.count(len(word2vec.wv.key_to_index)) for x in seq.tolist()]
        embedded = self.embeddings(seq)
        packed_embedded = pack_padded_sequence(embedded, seq_length, batch_first=True,enforce_sorted=False)
        packed_out, (hidden, cell) = self.lstm(packed_embedded)
        out, len_list = pad_packed_sequence(packed_out, batch_first=True) 
        mean_hidden = torch.sum(out, dim=1) / len_list.view(-1, 1).to(device)
        return nn.functional.normalize(mean_hidden, dim=1)

# %%
model = pcl.builder2.MoCo(SequenceEncoder,hidden_dim, batch_size_train, 0.999, 0.05).to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adagrad(model.parameters(), 0.005, weight_decay=1e-6)

# %% [markdown]
# **4. Training**

# %%
def compute_features(train_ds, model):
    model.eval()
    seq_label = [len(x)-x.count(len(word2vec.wv.key_to_index)) for x in train_ds.Encoded.tolist()]
    encoded_sequences = [torch.tensor(x) for x in train_ds.Encoded.tolist()]
    padded_sequence = pad_sequence(encoded_sequences, batch_first=True, 
                                   padding_value=len(word2vec.wv.key_to_index)).to(device)
    features = model(padded_sequence, is_eval=True, sequence_label=seq_label)   
    return features.cpu().numpy()

# %%
def run_kmeans(x, num_cluster, temperature):
    """
    Args:
        x: data to be clustered
    """

    results = {'im2cluster': [], 'centroids': [], 'density': []}

    # intialize faiss clustering parameters
    d = x.shape[1]
    k = int(num_cluster[0])
    clus = faiss.Clustering(d, k)
    clus.verbose = True
    clus.niter = 10
    clus.nredo = 5
    clus.seed = seed
    clus.max_points_per_centroid = 1000
    clus.min_points_per_centroid = 10

    res = faiss.StandardGpuResources()
    cfg = faiss.GpuIndexFlatConfig()
    cfg.useFloat16 = False
    cfg.device = 0
    index = faiss.GpuIndexFlatL2(res, d, cfg)

    clus.train(x, index)

    D, I = index.search(x, 3)  # for each sample, find cluster distance and assignments
    im2cluster = [int(n[0]) for n in I]
    # get cluster centroids
    centroids = faiss.vector_to_array(clus.centroids).reshape(k, d)

    # sample-to-centroid distances for each cluster 
    Dcluster = [[] for c in range(k)]
    for im, i in enumerate(im2cluster):
        Dcluster[i].append(D[im][0])

    # concentration estimation (phi)        
    density = np.zeros(k)
    for i, dist in enumerate(Dcluster):
        if len(dist) > 1:
            d = (np.asarray(dist) ** 0.5).mean() / np.log(len(dist) + 10)
            density[i] = d

            # if cluster only has one point, use the max to estimate its concentration
    dmax = density.max()
    for i, dist in enumerate(Dcluster):
        if len(dist) <= 1:
            density[i] = dmax

    density = density.clip(np.percentile(density, 10),
                           np.percentile(density, 90))  # clamp extreme values for stability
    density = temperature * density / density.mean()  # scale the mean to temperature

    # convert to cuda Tensors for broadcast
    centroids = torch.Tensor(centroids).cuda()
    centroids = nn.functional.normalize(centroids, p=2, dim=1)

    im2cluster = torch.LongTensor(im2cluster).cuda()
    density = torch.Tensor(density).cuda()

    results['centroids'] = centroids
    results['density'] = density
    results['im2cluster'] = im2cluster

    return results

# %%
def train_model(train_loader, model, criterion, optimizer, epoch, cluster_result=None):
    model.train()
    
    acc_epoch = []
    loss_epoch = []
    
    for index, sequence, label, _, sequence0, sequence1, _ in train_loader:
        pair0 = sequence0.to(device)
        pair1 = sequence1.to(device)
        label = torch.tensor(label).to(device)

        output, target, output_proto, target_proto = model(im_q=pair0, im_k=pair1, cluster_result=cluster_result, 
                                                           index = index, sequence_label=label)
        info_loss = criterion(output, target)
        
        # ProtoNCE loss
        if output_proto is not None:
            loss_proto = 0
            for proto_out,proto_target in zip(output_proto, target_proto):
                loss_proto += criterion(proto_out, proto_target)

            # average loss across all sets of prototypes
            loss_proto /= len(num_cluster)

        loss = loss_proto + loss_proto
#         print(loss_proto.item(), info_loss.item())

        loss_epoch.append(loss.item())

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    return np.mean(loss_epoch)

# %%
warnings.filterwarnings('ignore')

setup_seed()

best_val_acc_sequence = -1000
best_val_model = None

for i in range(epochs): 
    train_normal = train_ds[train_ds['Label']==0]
    train_abnormal = train_ds[train_ds['Label']==1]

    features_n = compute_features(train_normal, model)
    cluster_result_n = run_kmeans(features_n, num_cluster_n, 0.05)

    features_a = compute_features(train_abnormal, model)
    cluster_result_a = run_kmeans(features_a, num_cluster_a, 0.05)


    cluster_result_a['im2cluster'] = cluster_result_a['im2cluster'] + int(num_cluster_n[0])

    keys = ['im2cluster', 'centroids', 'density']
    cluster_result = {'im2cluster': [[], [], []], 'centroids': [[], [], []], 'density': [[], [], []]}

    for key in keys:
        cluster_result[key] = torch.cat((cluster_result_n[key], cluster_result_a[key]), 0)
    
    epoch_loss = train_model(train_loader, model, criterion, optimizer, i, cluster_result)  
    
    model.eval()
    
    correct_sequence = 0

    faiss_search = faiss.IndexFlatL2(cluster_result['centroids'].size(1))
    faiss_search.add(cluster_result['centroids'].detach().cpu().numpy())
    
#     with torch.no_grad():
#         for index, sequence, sequence_label, length, _, _ in val_loader:
#             true_label = []
#             pred_label = []
#             sequence = sequence.to(device)

#             true_label += sequence_label
#             sq = model.encoder_k(sequence).detach().cpu().numpy()
#             D, I = faiss_search.search(sq, 1)
#             pred_label += [1 if pred>2 else 0 for pred in I]

#             acc_sequence = (torch.tensor(true_label)==torch.tensor(pred_label)).sum().item()
#             correct_sequence += acc_sequence
            
#     if correct_sequence > best_val_acc_sequence:
#         best_val_acc_sequence = correct_sequence
#         best_val_model = deepcopy(model.state_dict())
       
    print(f'Epoch {i}: {epoch_loss}')
# Out:
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=14.2496 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.2464 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=14.2883 imbalance=1.037 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.244 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=14.2564 imbalance=1.032 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.33566 imbalance=1.195 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.41715 imbalance=1.095 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.34222 imbalance=1.179 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.38094 imbalance=1.283 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.47601 imbalance=1.364 nsplit=0
# Epoch 0: 7.901399354139964
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=14.3165 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.3113 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.3784 imbalance=1.039 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.3118 imbalance=1.025 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.3325 imbalance=1.031 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.40972 imbalance=1.221 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.50219 imbalance=1.168 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.43151 imbalance=1.187 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.44158 imbalance=1.350 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.58372 imbalance=1.403 nsplit=0
# Epoch 1: 6.9810166756312055
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=14.4639 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.455 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.5187 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.4476 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.4775 imbalance=1.034 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.4815 imbalance=1.221 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.54547 imbalance=1.162 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.49251 imbalance=1.072 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.52724 imbalance=1.407 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.65971 imbalance=1.372 nsplit=0
# Epoch 2: 6.793746372063954
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=14.6143 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.606 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=14.6795 imbalance=1.043 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.5909 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.6109 imbalance=1.030 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.55976 imbalance=1.226 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.64241 imbalance=1.143 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.59985 imbalance=1.058 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.58919 imbalance=1.329 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.74001 imbalance=1.345 nsplit=0
# Epoch 3: 6.744827886422475
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=14.7705 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.7619 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=14.8448 imbalance=1.038 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.7538 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.7662 imbalance=1.027 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.64802 imbalance=1.226 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.69845 imbalance=1.151 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.67363 imbalance=1.053 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.67771 imbalance=1.408 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.84733 imbalance=1.381 nsplit=0
# Epoch 4: 6.6552103360493975
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=14.9923 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.006 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=15.0848 imbalance=1.036 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=14.9724 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=14.9946 imbalance=1.026 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.75677 imbalance=1.218 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.81348 imbalance=1.140 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.74143 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.79803 imbalance=1.438 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.94434 imbalance=1.320 nsplit=0
# Epoch 5: 6.499783595403035
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=15.2189 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.1929 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=15.3023 imbalance=1.038 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=15.194 imbalance=1.035 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=15.213 imbalance=1.023 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.86818 imbalance=1.218 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.86057 imbalance=1.134 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.84743 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=2.95791 imbalance=1.330 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.06575 imbalance=1.280 nsplit=0
# Epoch 6: 6.501336634159088
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=15.439 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.4376 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.515 imbalance=1.038 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=15.4188 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=15.4452 imbalance=1.023 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=2.9831 imbalance=1.234 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.02304 imbalance=1.189 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=2.94922 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.0672 imbalance=1.330 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.13379 imbalance=1.218 nsplit=0
# Epoch 7: 6.437668899695079
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=15.7483 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.7545 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=15.8155 imbalance=1.037 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=15.7272 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=15.7683 imbalance=1.025 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.11922 imbalance=1.227 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.04394 imbalance=1.146 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=3.05393 imbalance=1.128 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.19703 imbalance=1.321 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.3164 imbalance=1.265 nsplit=0
# Epoch 8: 6.38287220398585
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=16.0907 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=16.0958 imbalance=1.031 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=16.1618 imbalance=1.041 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=16.0625 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=16.1232 imbalance=1.029 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.23675 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.16095 imbalance=1.137 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=3.19504 imbalance=1.112 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.34349 imbalance=1.321 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.44104 imbalance=1.207 nsplit=0
# Epoch 9: 6.384840110937755
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=16.4722 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=16.4583 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=16.5391 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=16.45 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=16.5293 imbalance=1.030 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.36188 imbalance=1.110 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.29327 imbalance=1.145 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=3.33719 imbalance=1.120 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.50205 imbalance=1.294 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.5708 imbalance=1.174 nsplit=0
# Epoch 10: 6.36038464307785
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=16.906 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=16.8969 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=16.9871 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=16.8856 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=16.9298 imbalance=1.027 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.50057 imbalance=1.103 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.42703 imbalance=1.195 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=3.49038 imbalance=1.130 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.67618 imbalance=1.285 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.73112 imbalance=1.194 nsplit=0
# Epoch 11: 6.329625467459361
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=17.3721 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=17.364 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=17.461 imbalance=1.043 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=17.3589 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=17.3741 imbalance=1.025 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.66061 imbalance=1.103 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.57845 imbalance=1.195 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=3.65576 imbalance=1.130 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.83167 imbalance=1.217 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=3.93998 imbalance=1.191 nsplit=0
# Epoch 12: 6.300112545490265
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=17.8734 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=17.8581 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=17.9723 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=17.8483 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=17.8637 imbalance=1.026 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.83475 imbalance=1.122 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.74077 imbalance=1.198 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=3.80016 imbalance=1.129 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.03524 imbalance=1.179 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.11881 imbalance=1.168 nsplit=0
# Epoch 13: 6.278784394264221
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=18.4097 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=18.389 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=18.4939 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=18.3805 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=18.3952 imbalance=1.026 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.00268 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=3.91516 imbalance=1.205 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=4.03672 imbalance=1.088 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.21596 imbalance=1.213 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.34002 imbalance=1.168 nsplit=0
# Epoch 14: 6.261094689369202
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=18.9817 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=18.9639 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=19.0575 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=18.9539 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=18.9669 imbalance=1.025 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.2075 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.1271 imbalance=1.155 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=4.24126 imbalance=1.093 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.35092 imbalance=1.212 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.56896 imbalance=1.147 nsplit=0
# Epoch 15: 6.2710809508959455
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=19.5795 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=19.5699 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=19.6577 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=19.5776 imbalance=1.038 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=19.5704 imbalance=1.026 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.42829 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.37438 imbalance=1.167 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.47133 imbalance=1.074 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=4.57389 imbalance=1.211 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.79877 imbalance=1.141 nsplit=0
# Epoch 16: 6.258113205432892
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=20.1963 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=20.1917 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=20.2899 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=20.1926 imbalance=1.036 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=20.1949 imbalance=1.026 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.662 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.50477 imbalance=1.210 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=4.70193 imbalance=1.074 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=4.83443 imbalance=1.183 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.0662 imbalance=1.140 nsplit=0
# Epoch 17: 6.2365103761355085
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=20.8498 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=20.8388 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=20.9378 imbalance=1.042 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=20.8423 imbalance=1.035 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=20.8492 imbalance=1.023 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.91028 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=4.78651 imbalance=1.162 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=4.95385 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=5.07751 imbalance=1.190 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.34842 imbalance=1.140 nsplit=0
# Epoch 18: 6.237847526868184
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=21.5064 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=21.4987 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=21.595 imbalance=1.041 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=21.4973 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=21.5118 imbalance=1.023 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=5.16983 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=5.03416 imbalance=1.162 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=5.1976 imbalance=1.059 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=5.31537 imbalance=1.171 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.64618 imbalance=1.144 nsplit=0
# Epoch 19: 6.212037622928619
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=22.1636 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=22.1632 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=22.2538 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=22.1566 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=22.172 imbalance=1.025 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=5.43397 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=5.23692 imbalance=1.199 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=5.45931 imbalance=1.059 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.52611 imbalance=1.138 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.9693 imbalance=1.144 nsplit=0
# Epoch 20: 6.193744162718455
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=22.8532 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=22.8617 imbalance=1.027 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=22.9555 imbalance=1.042 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=22.8483 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=22.8701 imbalance=1.025 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=5.72805 imbalance=1.104 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=5.78553 imbalance=1.130 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=5.73997 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=5.81304 imbalance=1.134 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=6.28793 imbalance=1.139 nsplit=0
# Epoch 21: 6.198850989341736
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=23.5426 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=23.5599 imbalance=1.025 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=23.6486 imbalance=1.041 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=23.5405 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=23.5657 imbalance=1.025 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.01838 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.36406 imbalance=1.307 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=6.02858 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=6.25582 imbalance=1.213 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=6.63042 imbalance=1.140 nsplit=0
# Epoch 22: 6.161372363567352
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=24.2484 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=24.2637 imbalance=1.025 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=24.3493 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=24.2462 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=24.2727 imbalance=1.024 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.32407 imbalance=1.101 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.67337 imbalance=1.307 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=6.33366 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=6.37707 imbalance=1.123 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=6.98996 imbalance=1.140 nsplit=0
# Epoch 23: 6.144947250684102
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=24.943 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=24.9554 imbalance=1.026 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=25.0431 imbalance=1.039 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=24.9404 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=24.9631 imbalance=1.024 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.61495 imbalance=1.109 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.00128 imbalance=1.285 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=6.64129 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=6.70313 imbalance=1.132 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=7.35914 imbalance=1.132 nsplit=0
# Epoch 24: 6.118396798769633
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=25.6419 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=25.646 imbalance=1.026 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=25.744 imbalance=1.039 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=25.6408 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=25.6567 imbalance=1.024 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=6.9168 imbalance=1.103 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.30234 imbalance=1.303 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=6.95561 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=7.00996 imbalance=1.132 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=7.71799 imbalance=1.140 nsplit=0
# Epoch 25: 6.119314213593801
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=26.3412 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=26.3346 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=26.4361 imbalance=1.037 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=26.3403 imbalance=1.032 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=26.3507 imbalance=1.024 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.22783 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.6067 imbalance=1.317 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=7.27603 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=7.36045 imbalance=1.134 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.09886 imbalance=1.141 nsplit=0
# Epoch 26: 6.147093951702118
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=27.0904 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=27.0899 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=27.193 imbalance=1.038 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=27.0896 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=27.0993 imbalance=1.024 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.52908 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.95029 imbalance=1.310 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=7.6159 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=7.87812 imbalance=1.220 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.52145 imbalance=1.140 nsplit=0
# Epoch 27: 6.138110399246216
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=27.8843 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=27.8843 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=27.9894 imbalance=1.035 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=27.883 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=27.8822 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=7.85342 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=8.30562 imbalance=1.301 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=7.97108 imbalance=1.058 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.21267 imbalance=1.232 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.94078 imbalance=1.140 nsplit=0
# Epoch 28: 6.123609562714894
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=28.7037 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=28.7025 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=28.8211 imbalance=1.036 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=28.7009 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=28.6956 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=8.16448 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=8.653 imbalance=1.301 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=8.34023 imbalance=1.060 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.57599 imbalance=1.218 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=9.41267 imbalance=1.140 nsplit=0
# Epoch 29: 6.103359401226044
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=29.5197 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=29.4873 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=29.6406 imbalance=1.035 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=29.4927 imbalance=1.027 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=29.4984 imbalance=1.021 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=8.51653 imbalance=1.087 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=9.01739 imbalance=1.302 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=8.7033 imbalance=1.060 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=8.65307 imbalance=1.107 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=9.84099 imbalance=1.138 nsplit=0
# Epoch 30: 6.107977469762166
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=30.3502 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=30.3391 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=30.4686 imbalance=1.034 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=30.3077 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=30.3163 imbalance=1.022 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=8.86828 imbalance=1.087 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=9.40283 imbalance=1.298 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=9.07204 imbalance=1.073 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=9.01745 imbalance=1.105 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=10.3094 imbalance=1.138 nsplit=0
# Epoch 31: 6.077905456225078
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=31.2146 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# ...
# Epoch 188: 5.468261659145355
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=128.695 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=128.695 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=128.697 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=128.695 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=128.695 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.013 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.7709 imbalance=1.102 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.336 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.1195 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.889 imbalance=1.137 nsplit=0
# Epoch 189: 5.467948218186696
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=128.995 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=128.995 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=128.997 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=128.995 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=128.995 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.1078 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.8738 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.42 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.236 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.9845 imbalance=1.138 nsplit=0
# Epoch 190: 5.4676523605982466
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=129.3 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=129.3 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=129.514 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=129.3 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=129.3 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.2059 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.9898 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.5075 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.3577 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.0995 imbalance=1.138 nsplit=0
# Epoch 191: 5.4673588673273725
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=129.608 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=129.608 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=129.823 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=129.608 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=129.608 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.3025 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.1038 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.5933 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.4753 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.2123 imbalance=1.138 nsplit=0
# Epoch 192: 5.467070281505585
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=129.916 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=129.916 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=130.056 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=129.916 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=129.916 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=43.399 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.2173 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.679 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.5934 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.3251 imbalance=1.138 nsplit=0
# Epoch 193: 5.466790874799092
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=130.228 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.228 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=130.368 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=130.228 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=130.228 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=42.4419 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.3312 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.7641 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.7126 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.438 imbalance=1.138 nsplit=0
# Epoch 194: 5.466515282789866
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=130.536 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.536 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=130.677 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=130.536 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=130.536 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=42.5307 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.4465 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.8502 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.8325 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.5527 imbalance=1.138 nsplit=0
# Epoch 195: 5.46624493598938
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=130.841 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=130.841 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=131.06 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=130.841 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=130.841 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=42.6183 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.5598 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=41.9352 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=44.9495 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.6657 imbalance=1.138 nsplit=0
# Epoch 196: 5.465978999932607
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=131.153 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.153 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=131.295 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=131.153 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.03 s, search 0.02 s): objective=131.153 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=42.593 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.6985 imbalance=1.102 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=42.0233 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.0729 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.7954 imbalance=1.132 nsplit=0
# Epoch 197: 5.465726613998413
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=131.47 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.47 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=131.612 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=131.47 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=131.47 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=42.6808 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=45.1484 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=42.1085 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.1912 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.8813 imbalance=1.133 nsplit=0
# Epoch 198: 5.46546745300293
# Clustering 1000 points in 256D to 3 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=131.786 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=131.786 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.02 s, search 0.01 s): objective=132.29 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=131.786 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.02 s, search 0.02 s): objective=131.786 imbalance=1.061 nsplit=0
# Clustering 200 points in 256D to 7 clusters, redo 5 times, 10 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=44.0565 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 9 (0.00 s, search 0.00 s): objective=45.263 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 9 (0.01 s, search 0.00 s): objective=42.1936 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.2509 imbalance=1.077 nsplit=0
# Outer iteration 4 / 5
#   Iteration 9 (0.01 s, search 0.01 s): objective=45.9946 imbalance=1.133 nsplit=0
# Epoch 199: 5.465215504169464

# %%
# model.load_state_dict(best_val_model)
model.eval()

faiss_search = faiss.IndexFlatL2(cluster_result['centroids'].size(1))
faiss_search.add(cluster_result['centroids'].detach().cpu().numpy())

true_label = []
pred_label = []

true_type_list = []
pred_type_list = []

for index, sequence, sequence_label, length, _, _, type in test_loader:
    sequence = sequence.to(device)
    true_type_list += type
    
    true_label += sequence_label
    sq = model.encoder_k(sequence).detach().cpu().numpy()
    D, I = faiss_search.search(sq, 1)
    pred_type_list += [i[0] for i in I]
    pred_label += [1 if pred>int(num_cluster_n[0])-1 else 0 for pred in I]

# %%
print(metrics.classification_report(true_label, pred_label, digits=4))
print(metrics.confusion_matrix(true_label, pred_label))

fpr, tpr, thresholds = metrics.roc_curve(true_label, pred_label, pos_label=1)
print(metrics.auc(fpr, tpr))

f = open('output.txt', 'a')
f.write('Anomaly detection on testing sequences:'+'\n')
f.write(str(metrics.classification_report(true_label, pred_label, digits=4))+'\n')
f.write(str(metrics.confusion_matrix(true_label, pred_label))+'\n')
f.write(str(metrics.auc(fpr, tpr))+'\n')
f.close()
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9657    0.9290    0.9470      1000
#            1     0.7017    0.8350    0.7626       200
#
#     accuracy                         0.9133      1200
#    macro avg     0.8337    0.8820    0.8548      1200
# weighted avg     0.9217    0.9133    0.9163      1200
#
# [[929  71]
#  [ 33 167]]
# 0.882

# %%
print(metrics.rand_score(true_type_list, pred_type_list))
print(metrics.mutual_info_score(true_type_list, pred_type_list))

f = open('output.txt', 'a')
f.write('Clustering results:'+'\n')
f.write('rand_score: ' + str(metrics.rand_score(true_type_list, pred_type_list))+'\n')
f.write('mutual_info_score: ' + str(metrics.mutual_info_score(true_type_list, pred_type_list))+'\n')
f.write('-'*50 + '\n')
f.close()
# Out:
# 0.7121809841534612
# 0.4826271390790803
